# %%
import pandas as pd
import requests
from scipy.stats import linregress
from matplotlib import pyplot as plt

# %%
data_path = "raw/application_data_cleaned_v1.csv"

# %%
defaulters_data = pd.read_csv(data_path)
defaulters_data.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100031       1         Cash loans           F            N
# 2      100047       1         Cash loans           M            N
# 3      100049       1         Cash loans           F            N
# 4      100096       1         Cash loans           F            N
#
#   FLAG_OWN_REALTY  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0               Y          202500.0    406597.5      24700.5         351000.0
# 1               Y          112500.0    979992.0      27076.5         702000.0
# 2               Y          202500.0   1193580.0      35028.0         855000.0
# 3               N          135000.0    288873.0      16258.5         238500.0
# 4               Y           81000.0    252000.0      14593.5         252000.0
#
#    ... FLAG_MOBIL FLAG_EMP_PHONE FLAG_WORK_PHONE FLAG_CONT_MOBILE  FLAG_PHONE  \
# ...

# %%
defaulters_data["SK_ID_CURR"].count()
# Out:
# 199998

# %%
defaulters_df = defaulters_data.loc[defaulters_data["TARGET"] == 1]
defaulters_df
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0          100002       1         Cash loans           M            N
# 1          100031       1         Cash loans           F            N
# 2          100047       1         Cash loans           M            N
# 3          100049       1         Cash loans           F            N
# 4          100096       1         Cash loans           F            N
# ...           ...     ...                ...         ...          ...
# 24820      456186       1         Cash loans           M            N
# 24821      456215       1         Cash loans           F            N
# 24822      456225       1         Cash loans           M            N
# 24823      456233       1         Cash loans           F            N
# 24824      456254       1         Cash loans           F            N
#
#       FLAG_OWN_REALTY  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# ...

# %%
non_defaulters_df = defaulters_data.loc[defaulters_data["TARGET"] == 0]
non_defaulters_df
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 24825       100003       0         Cash loans           F            N
# 24826       100004       0    Revolving loans           M            Y
# 24827       100006       0         Cash loans           F            N
# 24828       100007       0         Cash loans           M            N
# 24829       100008       0         Cash loans           M            N
# ...            ...     ...                ...         ...          ...
# 199993      321050       0         Cash loans           M            Y
# 199994      321052       0         Cash loans           M            Y
# 199995      321053       0    Revolving loans           M            Y
# 199996      321054       0         Cash loans           F            N
# 199997      321055       0         Cash loans           F            Y
#
#        FLAG_OWN_REALTY  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# ...
