# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
data_path = 'Resources/application_data_cleaned_v1.csv'

# %%
project_data = pd.read_csv(data_path)

# %%
project_data
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0           100002       1         Cash loans           M            N
# 1           100031       1         Cash loans           F            N
# 2           100047       1         Cash loans           M            N
# 3           100049       1         Cash loans           F            N
# 4           100096       1         Cash loans           F            N
# ...            ...     ...                ...         ...          ...
# 199993      321050       0         Cash loans           M            Y
# 199994      321052       0         Cash loans           M            Y
# 199995      321053       0    Revolving loans           M            Y
# 199996      321054       0         Cash loans           F            N
# 199997      321055       0         Cash loans           F            Y
#
#        FLAG_OWN_REALTY  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0                    Y          202500.0    406597.5      24700.5
# 1                    Y          112500.0    979992.0      27076.5
# 2                    Y          202500.0   1193580.0      35028.0
# 3                    N          135000.0    288873.0      16258.5
# 4                    Y           81000.0    252000.0      14593.5
# ...                ...               ...         ...          ...
# 199993               Y          675000.0    473760.0      49878.0
# 199994               Y          450000.0   1002870.0      42619.5
# 199995               Y          450000.0   1350000.0      67500.0
# 199996               Y          202500.0    331920.0      18135.0
# 199997               N          202500.0    592560.0      35937.0
#
#         AMT_GOODS_PRICE  ... FLAG_MOBIL FLAG_EMP_PHONE FLAG_WORK_PHONE  \
# 0              351000.0  ...          1              1               0
# 1              702000.0  ...          1              1               0
# 2              855000.0  ...          1              1               0
# 3              238500.0  ...          1              1               1
# 4              252000.0  ...          1              0               0
# ...                 ...  ...        ...            ...             ...
# 199993         450000.0  ...          1              1               0
# 199994         922500.0  ...          1              1               0
# 199995        1350000.0  ...          1              1               0
# 199996         225000.0  ...          1              1               0
# 199997         450000.0  ...          1              1               0
#
#        FLAG_CONT_MOBILE  FLAG_PHONE  FLAG_EMAIL  OCCUPATION_TYPE  \
# 0                     1           1           0         Laborers
# 1                     1           0           0    Cooking staff
# 2                     1           0           0         Laborers
# 3                     1           1           0      Sales staff
# 4                     1           0           0              NaN
# ...                 ...         ...         ...              ...
# 199993                1           0           0         Laborers
# 199994                1           0           0         Managers
# 199995                1           0           0         Managers
# 199996                1           0           0       Core staff
# 199997                1           0           0         Laborers
#
#         REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  \
# 0                          2                            2
# 1                          3                            2
# 2                          2                            2
# 3                          3                            3
# 4                          2                            2
# ...                      ...                          ...
# 199993                     2                            2
# 199994                     2                            2
# 199995                     1                            1
# 199996                     2                            2
# 199997                     2                            2
#
#              ORGANIZATION_TYPE
# 0       Business Entity Type 3
# 1       Business Entity Type 3
# 2       Business Entity Type 3
# 3                Self-employed
# 4                          XNA
# ...                        ...
# 199993            Construction
# 199994            Construction
# 199995  Business Entity Type 3
# 199996                  School
# 199997  Business Entity Type 3
#
# [199998 rows x 27 columns]

# %%
jobs = project_data.groupby(['OCCUPATION_TYPE'], as_index=False)['SK_ID_CURR'].count()
jobs
# Out:
#           OCCUPATION_TYPE  SK_ID_CURR
# 0             Accountants        6306
# 1          Cleaning staff        3010
# 2           Cooking staff        3932
# 3              Core staff       17757
# 4                 Drivers       12366
# 5                HR staff         364
# 6   High skill tech staff        7254
# 7                IT staff         333
# 8                Laborers       36390
# 9      Low-skill Laborers        1429
# 10               Managers       13719
# 11         Medicine staff        5531
# 12  Private service staff        1699
# 13          Realty agents         467
# 14            Sales staff       20943
# 15            Secretaries         833
# 16         Security staff        4473
# 17   Waiters/barmen staff         876

# %%
plt.bar(jobs['OCCUPATION_TYPE'], jobs['SK_ID_CURR'])
plt.xticks(rotation="vertical")
plt.xlabel("Occupations")
plt.ylabel("Total #")
plt.show()

# %%
project_data.groupby(['TARGET'], as_index=False)['OCCUPATION_TYPE'].count()
# Out:
#    TARGET  OCCUPATION_TYPE
# 0       0           119135
# 1       1            18547

# %%
credit_card_defaulter = project_data[project_data['TARGET'] == 1]
credit_card_defaulter
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0          100002       1         Cash loans           M            N
# 1          100031       1         Cash loans           F            N
# 2          100047       1         Cash loans           M            N
# 3          100049       1         Cash loans           F            N
# 4          100096       1         Cash loans           F            N
# ...           ...     ...                ...         ...          ...
# 24820      456186       1         Cash loans           M            N
# 24821      456215       1         Cash loans           F            N
# 24822      456225       1         Cash loans           M            N
# 24823      456233       1         Cash loans           F            N
# 24824      456254       1         Cash loans           F            N
#
#       FLAG_OWN_REALTY  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0                   Y          202500.0    406597.5      24700.5
# 1                   Y          112500.0    979992.0      27076.5
# 2                   Y          202500.0   1193580.0      35028.0
# 3                   N          135000.0    288873.0      16258.5
# 4                   Y           81000.0    252000.0      14593.5
# ...               ...               ...         ...          ...
# 24820               N          207000.0    450000.0      32746.5
# 24821               N          144000.0   1303200.0      46809.0
# 24822               Y          225000.0    297000.0      19975.5
# 24823               Y          225000.0    521280.0      23089.5
# 24824               Y          171000.0    370107.0      20205.0
#
#        AMT_GOODS_PRICE  ... FLAG_MOBIL FLAG_EMP_PHONE FLAG_WORK_PHONE  \
# 0             351000.0  ...          1              1               0
# 1             702000.0  ...          1              1               0
# 2             855000.0  ...          1              1               0
# 3             238500.0  ...          1              1               1
# 4             252000.0  ...          1              0               0
# ...                ...  ...        ...            ...             ...
# 24820         450000.0  ...          1              1               1
# 24821        1125000.0  ...          1              1               1
# 24822         297000.0  ...          1              1               0
# 24823         450000.0  ...          1              1               0
# 24824         319500.0  ...          1              1               0
#
#       FLAG_CONT_MOBILE  FLAG_PHONE  FLAG_EMAIL  OCCUPATION_TYPE  \
# 0                    1           1           0         Laborers
# 1                    1           0           0    Cooking staff
# 2                    1           0           0         Laborers
# 3                    1           1           0      Sales staff
# 4                    1           0           0              NaN
# ...                ...         ...         ...              ...
# 24820                1           0           0         Laborers
# 24821                1           0           0         Laborers
# 24822                1           1           0         Managers
# 24823                1           0           0      Sales staff
# 24824                1           0           0         Laborers
#
#        REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  \
# 0                         2                            2
# 1                         3                            2
# 2                         2                            2
# 3                         3                            3
# 4                         2                            2
# ...                     ...                          ...
# 24820                     3                            3
# 24821                     2                            2
# 24822                     2                            2
# 24823                     2                            2
# 24824                     2                            2
#
#             ORGANIZATION_TYPE
# 0      Business Entity Type 3
# 1      Business Entity Type 3
# 2      Business Entity Type 3
# 3               Self-employed
# 4                         XNA
# ...                       ...
# 24820  Business Entity Type 3
# 24821            Construction
# 24822  Business Entity Type 3
# 24823  Business Entity Type 3
# 24824  Business Entity Type 1
#
# [24825 rows x 27 columns]

# %%
default_jobs = credit_card_defaulter.groupby(['OCCUPATION_TYPE'], as_index=False)['SK_ID_CURR'].count()

# %%
plt.bar(default_jobs['OCCUPATION_TYPE'], default_jobs['SK_ID_CURR'])
plt.xticks(rotation="vertical")
plt.xlabel("Occupations")
plt.ylabel("Total #")
plt.title("Occupations of Credit Card Defaulters")
plt.show()

# %%
non_defaulter = project_data[project_data['TARGET'] == 0]
non_defaulter
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 24825       100003       0         Cash loans           F            N
# 24826       100004       0    Revolving loans           M            Y
# 24827       100006       0         Cash loans           F            N
# 24828       100007       0         Cash loans           M            N
# 24829       100008       0         Cash loans           M            N
# ...            ...     ...                ...         ...          ...
# 199993      321050       0         Cash loans           M            Y
# 199994      321052       0         Cash loans           M            Y
# 199995      321053       0    Revolving loans           M            Y
# 199996      321054       0         Cash loans           F            N
# 199997      321055       0         Cash loans           F            Y
#
#        FLAG_OWN_REALTY  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 24825                N          270000.0   1293502.5      35698.5
# 24826                Y           67500.0    135000.0       6750.0
# 24827                Y          135000.0    312682.5      29686.5
# 24828                Y          121500.0    513000.0      21865.5
# 24829                Y           99000.0    490495.5      27517.5
# ...                ...               ...         ...          ...
# 199993               Y          675000.0    473760.0      49878.0
# 199994               Y          450000.0   1002870.0      42619.5
# 199995               Y          450000.0   1350000.0      67500.0
# 199996               Y          202500.0    331920.0      18135.0
# 199997               N          202500.0    592560.0      35937.0
#
#         AMT_GOODS_PRICE  ... FLAG_MOBIL FLAG_EMP_PHONE FLAG_WORK_PHONE  \
# 24825         1129500.0  ...          1              1               0
# 24826          135000.0  ...          1              1               1
# 24827          297000.0  ...          1              1               0
# 24828          513000.0  ...          1              1               0
# 24829          454500.0  ...          1              1               1
# ...                 ...  ...        ...            ...             ...
# 199993         450000.0  ...          1              1               0
# 199994         922500.0  ...          1              1               0
# 199995        1350000.0  ...          1              1               0
# 199996         225000.0  ...          1              1               0
# 199997         450000.0  ...          1              1               0
#
#        FLAG_CONT_MOBILE  FLAG_PHONE  FLAG_EMAIL  OCCUPATION_TYPE  \
# 24825                 1           1           0       Core staff
# 24826                 1           1           0         Laborers
# 24827                 1           0           0         Laborers
# 24828                 1           0           0       Core staff
# 24829                 1           1           0         Laborers
# ...                 ...         ...         ...              ...
# 199993                1           0           0         Laborers
# 199994                1           0           0         Managers
# 199995                1           0           0         Managers
# 199996                1           0           0       Core staff
# 199997                1           0           0         Laborers
#
#         REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  \
# 24825                      1                            1
# 24826                      2                            2
# 24827                      2                            2
# 24828                      2                            2
# 24829                      2                            2
# ...                      ...                          ...
# 199993                     2                            2
# 199994                     2                            2
# 199995                     1                            1
# 199996                     2                            2
# 199997                     2                            2
#
#              ORGANIZATION_TYPE
# 24825                   School
# 24826               Government
# 24827   Business Entity Type 3
# 24828                 Religion
# 24829                    Other
# ...                        ...
# 199993            Construction
# 199994            Construction
# 199995  Business Entity Type 3
# 199996                  School
# 199997  Business Entity Type 3
#
# [175173 rows x 27 columns]

# %%
non_default_jobs = non_defaulter.groupby(['OCCUPATION_TYPE'], as_index=False)['SK_ID_CURR'].count()

# %%
plt.bar(non_default_jobs['OCCUPATION_TYPE'], non_default_jobs['SK_ID_CURR'])
plt.xticks(rotation="vertical")
plt.xlabel("Occupations")
plt.ylabel("Total #")
plt.title("Occupations of Non Credit Card Defaulters")
plt.show()

# %%
loans = credit_card_defaulter.groupby(['NAME_CONTRACT_TYPE'], as_index = False)['OCCUPATION_TYPE'].count()

# %%
loans1 = non_defaulter.groupby(['NAME_CONTRACT_TYPE'], as_index = False)['OCCUPATION_TYPE'].count()

# %%
plt.pie(loans['OCCUPATION_TYPE'],  autopct="%1.1f%%", labels=(loans['NAME_CONTRACT_TYPE']))
# Out:
# ([<matplotlib.patches.Wedge at 0x169a75e90>,
#   <matplotlib.patches.Wedge at 0x17304a090>],
#  [Text(-1.075356900225917, 0.23153301521922898, 'Cash loans'),
#   Text(1.0753569056453378, -0.23153299004868452, 'Revolving loans')],
#  [Text(-0.5865583092141364, 0.12629073557412487, '93.2%'),
#   Text(0.5865583121701842, -0.126290721844737, '6.8%')])

# %%
plt.pie(loans1['OCCUPATION_TYPE'],  autopct="%1.1f%%", labels=(loans1['NAME_CONTRACT_TYPE']))
# Out:
# ([<matplotlib.patches.Wedge at 0x17308f9d0>,
#   <matplotlib.patches.Wedge at 0x173098fd0>],
#  [Text(-1.0398942984795314, 0.35863609409785197, 'Cash loans'),
#   Text(1.0398943068740145, -0.35863606975736956, 'Revolving loans')],
#  [Text(-0.5672150718979262, 0.19561968768973742, '89.4%'),
#   Text(0.5672150764767352, -0.19561967441311065, '10.6%')])

# %%
#could look at if there is a significant difference between these, but i doubt...
